# %% [markdown]
# <a href="https://colab.research.google.com/github/kowalsp/data_science/blob/main/matplotlib_wyswietlanie_obrazow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('sample_data/zdjecietatry.jpg')

# %%
img
# Out:
# array([[[135, 134,  80],
#         [133, 130,  87],
#         [127, 122, 100],
#         ...,
#         [241, 242, 247],
#         [239, 240, 245],
#         [238, 239, 244]],
#
#        [[102, 100,  49],
#         [ 89,  86,  43],
#         [108, 103,  81],
#         ...,
#         [240, 241, 246],
#         [240, 241, 246],
#         [239, 240, 245]],
#
#        [[ 92,  90,  41],
#         [ 71,  68,  27],
#         [ 89,  84,  62],
#         ...,
#         [239, 240, 245],
#         [239, 240, 245],
#         [240, 241, 246]],
#
#        ...,
#
#        [[114, 125,  82],
#         [133, 144, 101],
#         [137, 150, 104],
#         ...,
#         [ 99, 103,  66],
#         [107, 111,  74],
#         [ 96, 101,  61]],
#
#        [[117, 128,  85],
#         [131, 142,  99],
#         [139, 152, 106],
#         ...,
#         [113, 117,  80],
#         [112, 116,  79],
#         [ 95,  99,  62]],
#
#        [[122, 133,  90],
#         [130, 141,  98],
#         [141, 154, 108],
# ...

# %%
img.shape
# Out:
# (1588, 3264, 3)

# %%
plt.imshow(img)
plt.axis('Off')
# Out:
# (-0.5, 3263.5, 1587.5, -0.5)

# %%
fig = plt.figure(figsize=(12,10))
plt.subplot(221)
plt.imshow(mpimg.imread('sample_data/zdjecietatry.jpg'))
plt.axis('Off')
plt.subplot(222)
plt.imshow(mpimg.imread('sample_data/zdjecie2.jpg'))
plt.axis('Off')
plt.subplot(223)
plt.imshow(mpimg.imread('sample_data/zdjecie3.jpg'))
plt.axis('Off')
plt.subplot(224)
plt.imshow(mpimg.imread('sample_data/zdjecie4.jpg'))
plt.axis('Off')
# Out:
# (-0.5, 3263.5, 1587.5, -0.5)

# %%
for idx, img in enumerate(['sample_data/zdjecietatry.jpg','sample_data/zdjecie2.jpg','sample_data/zdjecie3.jpg','sample_data/zdjecie4.jpg']):
  plt.subplot(220+idx+1)
  plt.imshow(mpimg.imread(img))
  plt.axis('Off')

# %%
for idx, img in enumerate(['sample_data/zdjecietatry.jpg','sample_data/zdjecie2.jpg','sample_data/zdjecie3.jpg','sample_data/zdjecie4.jpg']):
  plt.subplot(140+idx+1)
  plt.imshow(mpimg.imread(img))
  plt.axis('Off')
