# %% [markdown]
# <a href="https://colab.research.google.com/github/kowalsp/data_science/blob/main/app_store_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
print(np.__version__)
print(pd.__version__)
# Out:
# 1.23.5
# 1.5.3

# %%
url = 'https://storage.googleapis.com/esmartdata-courses-files/ds-bootcamp/appstore_games.csv'

# %%
df_raw = pd.read_csv(url)

# %%
df_raw.head()
# Out:
#                                                  URL         ID  \
# 0   https://apps.apple.com/us/app/sudoku/id284921427  284921427
# 1  https://apps.apple.com/us/app/reversi/id284926400  284926400
# 2  https://apps.apple.com/us/app/morocco/id284946595  284946595
# 3  https://apps.apple.com/us/app/sudoku-free/id28...  285755462
# 4  https://apps.apple.com/us/app/senet-deluxe/id2...  285831220
#
#             Name Subtitle                                           Icon URL  \
# 0         Sudoku      NaN  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 1        Reversi      NaN  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 2        Morocco      NaN  https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# 3  Sudoku (Free)      NaN  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 4   Senet Deluxe      NaN  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
#
#    Average User Rating  User Rating Count  Price In-app Purchases  \
# ...

# %%
df_raw.columns
# Out:
# Index(['URL', 'ID', 'Name', 'Subtitle', 'Icon URL', 'Average User Rating',
#        'User Rating Count', 'Price', 'In-app Purchases', 'Description',
#        'Developer', 'Age Rating', 'Languages', 'Size', 'Primary Genre',
#        'Genres', 'Original Release Date', 'Current Version Release Date'],
#       dtype='object')

# %%
df = df_raw.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17007 entries, 0 to 17006
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   URL                           17007 non-null  object
#  1   ID                            17007 non-null  int64
#  2   Name                          17007 non-null  object
#  3   Subtitle                      5261 non-null   object
#  4   Icon URL                      17007 non-null  object
#  5   Average User Rating           7561 non-null   float64
#  6   User Rating Count             7561 non-null   float64
#  7   Price                         16983 non-null  float64
#  8   In-app Purchases              7683 non-null   object
#  9   Description                   17007 non-null  object
#  10  Developer                     17007 non-null  object
#  11  Age Rating                    17007 non-null  object
# ...

# %%
df = df.drop(columns= ['URL', 'Icon URL','Subtitle','Description','In-app Purchases'])

# %%
df
# Out:
#                ID                       Name  Average User Rating  \
# 0       284921427                     Sudoku                  4.0
# 1       284926400                    Reversi                  3.5
# 2       284946595                    Morocco                  3.0
# 3       285755462              Sudoku (Free)                  3.5
# 4       285831220               Senet Deluxe                  3.5
# ...           ...                        ...                  ...
# 17002  1474626442  Stack Puzzle : Rise Tower                  NaN
# 17003  1474919257                  EachOther                  NaN
# 17004  1474962324         Rabbit Vs Tortoise                  NaN
# 17005  1474963671                     FaTaLL                  NaN
# 17006  1475076711   The Three Kingdoms :Bomb                  NaN
#
#        User Rating Count  Price                 Developer Age Rating  \
# 0                 3553.0   2.99  Mighty Mighty Good Games         4+
# ...

# %%
df.set_index('ID')
# Out:
#                                  Name  Average User Rating  User Rating Count  \
# ID
# 284921427                      Sudoku                  4.0             3553.0
# 284926400                     Reversi                  3.5              284.0
# 284946595                     Morocco                  3.0             8376.0
# 285755462               Sudoku (Free)                  3.5           190394.0
# 285831220                Senet Deluxe                  3.5               28.0
# ...                               ...                  ...                ...
# 1474626442  Stack Puzzle : Rise Tower                  NaN                NaN
# 1474919257                  EachOther                  NaN                NaN
# 1474962324         Rabbit Vs Tortoise                  NaN                NaN
# 1474963671                     FaTaLL                  NaN                NaN
# 1475076711   The Three Kingdoms :Bomb                  NaN                NaN
#
# ...

# %%
df.describe()
# Out:
#                  ID  Average User Rating  User Rating Count         Price  \
# count  1.700700e+04          7561.000000       7.561000e+03  16983.000000
# mean   1.059614e+09             4.060905       3.306531e+03      0.813419
# std    2.999676e+08             0.751428       4.232256e+04      7.835732
# min    2.849214e+08             1.000000       5.000000e+00      0.000000
# 25%    8.996543e+08             3.500000       1.200000e+01      0.000000
# 50%    1.112286e+09             4.500000       4.600000e+01      0.000000
# 75%    1.286983e+09             4.500000       3.090000e+02      0.000000
# max    1.475077e+09             5.000000       3.032734e+06    179.990000
#
#                Size
# count  1.700600e+04
# mean   1.157064e+08
# std    2.036477e+08
# min    5.132800e+04
# 25%    2.295014e+07
# 50%    5.676895e+07
# 75%    1.330271e+08
# max    4.005591e+09

# %%
df.describe(include=['object']).T
# Out:
#                               count unique  \
# Name                          17007  16847
# Developer                     17007   8693
# Age Rating                    17007      4
# Languages                     16947    990
# Primary Genre                 17007     21
# Genres                        17007   1004
# Original Release Date         17007   3084
# Current Version Release Date  17007   2512
#
#                                                                      top  \
# Name                                                           Additions
# Developer                     Tapps Tecnologia da Informa\xe7\xe3o Ltda.
# Age Rating                                                            4+
# Languages                                                             EN
# Primary Genre                                                      Games
# Genres                                           Games, Strategy, Puzzle
# ...

# %%
df.columns = [col.lower().replace('_','') for col in df.columns]

# %%
df.head()
# Out:
#           id           name  averageuserrating  userratingcount  price  \
# 0  284921427         Sudoku                4.0           3553.0   2.99
# 1  284926400        Reversi                3.5            284.0   1.99
# 2  284946595        Morocco                3.0           8376.0   0.00
# 3  285755462  Sudoku (Free)                3.5         190394.0   0.00
# 4  285831220   Senet Deluxe                3.5             28.0   2.99
#
#                   developer agerating  \
# 0  Mighty Mighty Good Games        4+
# 1          Kiss The Machine        4+
# 2               Bayou Games        4+
# 3  Mighty Mighty Good Games        4+
# 4           RoGame Software        4+
#
#                                            languages        size primarygenre  \
# 0  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...  15853568.0        Games
# 1                                                 EN  12328960.0        Games
# ...

# %%
df.primarygenre.value_counts()
# Out:
# Games                16286
# Education              222
# Entertainment          198
# Utilities               77
# Sports                  60
# Reference               32
# Stickers                29
# Finance                 18
# Business                16
# Productivity            15
# Lifestyle               10
# Book                     9
# Social Networking        9
# News                     7
# Health & Fitness         5
# Food & Drink             4
# Music                    3
# Navigation               3
# Medical                  2
# Travel                   1
# Shopping                 1
# Name: primarygenre, dtype: int64

# %%
df.primarygenre.value_counts().nlargest(5)
# Out:
# Games            16286
# Education          222
# Entertainment      198
# Utilities           77
# Sports              60
# Name: primarygenre, dtype: int64

# %%
list(df.primarygenre.value_counts().nlargest(5).index)
# Out:
# ['Games', 'Education', 'Entertainment', 'Utilities', 'Sports']

# %%
import seaborn as sns

# %%
sns.set()

# %%
_ = df.agerating.value_counts().plot(kind='pie')

# %%
df.price.value_counts()
# Out:
# 0.00      14212
# 0.99       1078
# 1.99        515
# 2.99        471
# 4.99        237
# 3.99        163
# 9.99         88
# 11.99        59
# 5.99         42
# 6.99         32
# 179.99       30
# 7.99         17
# 8.99         13
# 19.99         9
# 14.99         4
# 12.99         3
# 16.99         2
# 29.99         2
# 139.99        1
# 99.99         1
# 37.99         1
# 36.99         1
# 18.99         1
# 59.99         1
# Name: price, dtype: int64

# %%
df.averageuserrating.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='averageuserrating'>

# %%
df['num_lang'] = df.languages.str.split(', ').str.len()
df.head()
# Out:
#           id           name  averageuserrating  userratingcount  price  \
# 0  284921427         Sudoku                4.0           3553.0   2.99
# 1  284926400        Reversi                3.5            284.0   1.99
# 2  284946595        Morocco                3.0           8376.0   0.00
# 3  285755462  Sudoku (Free)                3.5         190394.0   0.00
# 4  285831220   Senet Deluxe                3.5             28.0   2.99
#
#                   developer agerating  \
# 0  Mighty Mighty Good Games        4+
# 1          Kiss The Machine        4+
# 2               Bayou Games        4+
# 3  Mighty Mighty Good Games        4+
# 4           RoGame Software        4+
#
#                                            languages        size primarygenre  \
# 0  DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...  15853568.0        Games
# 1                                                 EN  12328960.0        Games
# ...

# %%
df.num_lang.value_counts()
# Out:
# 1.0      12566
# 2.0       1102
# 3.0        495
# 16.0       316
# 4.0        261
# 5.0        247
# 6.0        220
# 25.0       171
# 9.0        154
# 11.0       147
# 8.0        142
# 7.0        140
# 10.0       140
# 31.0       133
# 12.0        91
# 21.0        77
# 14.0        64
# 13.0        64
# 15.0        54
# 17.0        37
# 30.0        35
# 19.0        34
# 32.0        34
# 33.0        33
# 22.0        31
# 18.0        24
# 46.0        20
# 26.0        18
# 20.0        14
# 24.0        13
# 23.0        11
# 27.0        11
# 28.0         9
# 29.0         8
# 45.0         6
# 44.0         5
# 65.0         4
# 42.0         3
# 43.0         3
# 36.0         2
# 49.0         2
# 48.0         1
# 66.0         1
# 35.0         1
# 34.0         1
# 111.0        1
# 76.0         1
# Name: num_lang, dtype: int64

# %%
df.averageuserrating.value_counts(dropna=False)
# Out:
# NaN    9446
# 4.5    2861
# 4.0    1722
# 5.0     990
# 3.5     925
# 3.0     514
# 2.5     317
# 2.0     158
# 1.5      60
# 1.0      14
# Name: averageuserrating, dtype: int64

# %%
df.isnull().sum()
# Out:
# id                              0
# name                            0
# averageuserrating            9446
# userratingcount              9446
# price                          24
# developer                       0
# agerating                       0
# languages                      60
# size                            1
# primarygenre                    0
# genres                          0
# originalreleasedate             0
# currentversionreleasedate       0
# num_lang                       60
# dtype: int64
