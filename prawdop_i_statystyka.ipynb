# %% [markdown]
# <a href="https://colab.research.google.com/github/kowalsp/data_science/blob/main/prawdop_i_statystyka.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import seaborn as sns

# %%
from scipy.stats import norm

# %%
sns.set()

# %%
mu = 0

# %%
sigma = 1

# %%
x = np.linspace(mu-3*sigma, mu+3*sigma , 100)

# %%
plt.plot(x, norm.pdf(x,mu, sigma))
